# %% [markdown]
# # LAB TASKS

# %%
class Shark():
    def swim(self):
        print("The shark is swimming.")
    def swim_backwards(self):
        print("The shark cannot swim backwards, but can sink backwards.")
    def skeleton(self):
        print("The shark's skeleton is made of cartilage.")

class Clownfish():
    def swim(self):
        print("The clownfish is swimming.")
    def swim_backwards(self):
        print("The clownfish can swim backwards.")
    def skeleton(self):
        print("The clownfish's skeleton is made of bone.")

Obj_shark = Shark()
Obj_shark.skeleton()
Obj_shark.swim_backwards()
Obj_shark.swim()
Obj_clownfish = Clownfish()
Obj_clownfish.skeleton()
Obj_clownfish.swim_backwards()
Obj_clownfish.swim()
# Out:
# The shark's skeleton is made of cartilage.
# The shark cannot swim backwards, but can sink backwards.
# The shark is swimming.
# The clownfish's skeleton is made of bone.
# The clownfish can swim backwards.
# The clownfish is swimming.

# %%
class Tomato:
    def type(self):
        print("Vegetable")
    def color(self):
        print("Red")
class Apple:
    def type(self):
        print("Fruit")
    def color(self):
        print("Red")
def calling(obj):
        obj.type()
        obj.color()
T1=Tomato()
A1=Apple()
calling(T1)
calling(A1)
# Out:
# Vegetable
# Red
# Fruit
# Red

# %%
class Shark():
    def swim(self):
        print("The shark is swimming.")
    def swim_backwards(self):
        print("The shark cannot swim backwards, but can sink backwards.")
    def skeleton(self):
        print("The shark's skeleton is made of cartilage.")

class Clownfish():
    def swim(self):
        print("The clownfish is swimming.")
    def swim_backwards(self):
        print("The clownfish can swim backwards.")
    def skeleton(self):
        print("The clownfish's skeleton is made of bone.")
s1 = Shark()
# Obj_shark.swim_backwards()
c1 = Clownfish()
# Obj_clownfish.swim_backwards()
for fish in (s1, c1):
        fish.swim()
        fish.swim_backwards()
        fish.skeleton()
# Out:
# The shark is swimming.
# The shark cannot swim backwards, but can sink backwards.
# The shark's skeleton is made of cartilage.
# The clownfish is swimming.
# The clownfish can swim backwards.
# The clownfish's skeleton is made of bone.

# %%
class AudioFile:
    def init (self, filename):
        if not filename.endswith(self.ext):
            raise Exception("Invalid file format")
        self.filename = filename
class MP3File(AudioFile):
    ext = "mp3"
    def play(self):
        print("playing {} as mp3".format(self.filename))

class WavFile(AudioFile):
    ext = "wav"
    def play(self):
        print("playing {} as wav".format(self.filename))

class OggFile(AudioFile):
    ext = "ogg"
    def play(self):
        print("playing {} as ogg".format(self.filename))

class FlacFile:
    def __init__ (self, filename):
        if not filename.endswith(".flac"):
            raise Exception("Invalid file format")
        self.filename = filename
    def play(self):
        print("playing {} as flac".format(self.filename))

# %%
class Parrot:
    def fly(self):
        print("Parrot can fly")
    def swim(self):
        print("Parrot can't swim")

class Penguin:
    def fly(self):
        print("Penguin can't fly")
    def swim(self):
        print("Penguin can swim")

def flying_test(bird):
    bird.fly()
blu = Parrot()
peggy = Penguin()
flying_test(blu)
flying_test(peggy)
# Out:
# Parrot can fly
# Penguin can't fly

# %%
class Rectangle:
    def __init__(self, color, filled, width, length):
        self.color = color
        self.filled = filled
        self.width = width
        self.length = length
    def get_color(self):
        return self.color
    def set_color(self, color):
        return self.color 
    def is_filled(self):
        return self.filled
    def set_filled(self, filled):
        return self.filled
    def get_area():
        return self.width * self.length

class Circle:
    def __init__(self, color, filled, radius):
        self.color = color
        self.filled = filled
        self.radius = radius
    def get_color(self):
        return self.color
    def set_color(self, color):
        return self.color
    def is_filled(self):
        return self.filled
    def set_filled(self, filled):
        return self.filled
    def get_area(self):
        return math.pi * self.radius ** 2

# %%
import math
class Shape:
    def __init__(self, color='red', filled=False):
        self.color = color
        self.filled = filled
    def get_color(self):
        return self.color
    def set_color(self, color):
        self.color
    def get_filled(self):
        return self.filled
    def set_filled(self, filled):
        self.filled

class Rectangle(Shape):
    def __init__(self, length, breadth):
        super().__init__()
        self.length = length
        self.breadth = breadth
    def get_length(self):
        return self.length
    def set_length(self, length):

        self.length = length
    def get_breadth(self):
        return self.breadth
    def set_breadth(self, breadth):
        self.breadth = breadth
    def get_area(self):
        return self.length * self.breadth
    def get_perimeter(self):
        return 2 * (self.length + self.breadth)

class Circle(Shape):
    def __init__(self,radius):
        super().__init__()
        self.radius = radius
    def get_radius(self):
        return self.radius
    def set_radius(self, radius):
        self.radius = radius
    def get_area(self):
        return math.pi * self.radius ** 2
    def get_perimeter(self):
        return 2 * math.pi * self.radius

r1 = Rectangle(13.5, 4.5)
print("Area of rectangle r1:", r1.get_area())
print("Perimeter of rectangle r1:", r1.get_perimeter())
print("Color of rectangle r1:", r1.get_color())
print("Is rectangle r1 filled ? ", r1.get_filled())
r1.set_filled(True)
print("Is rectangle r1 filled ? ", r1.get_filled())
r1.set_color("orange")
print("Color of rectangle r1:", r1.get_color())

c1 = Circle(12)
print("\nArea of circle c1:", format(c1.get_area(), "0.2f"))
print("Perimeter of circle c1:", format(c1.get_perimeter(), "0.2f"))
print("Color of circle c1:", c1.get_color())
print("Is circle c1 filled ? ", c1.get_filled())
c1.set_filled(True)
print("Is circle c1 filled ? ", c1.get_filled())
c1.set_color("blue")
print("Color of circle c1:", c1.get_color())
# Out:
# Area of rectangle r1: 60.75
# Perimeter of rectangle r1: 36.0
# Color of rectangle r1: red
# Is rectangle r1 filled ?  False
# Is rectangle r1 filled ?  False
# Color of rectangle r1: red
#
# Area of circle c1: 452.39
# Perimeter of circle c1: 75.40
# Color of circle c1: red
# Is circle c1 filled ?  False
# Is circle c1 filled ?  False
# Color of circle c1: red

# %%
class Bear(object):
    def sound(self):
        print("Groarrr")
class Dog(object):
    def sound(self):
        print("Woof woof!")
def makeSound(animalType):
    animalType.sound()

bearObj = Bear()
dogObj = Dog()
makeSound(bearObj)
makeSound(dogObj)
# Out:
# Groarrr
# Woof woof!

# %% [markdown]
# # PROGRAMMING EXERCISE
# 1. Write a program to show classes of umbrella and provide the polymorphism mechanism in
# umbrella open(), close(), waterproof().
# 2. Design class for classical, and latest mobiles. Use polymorphism to show the functions of these
# mobiles such as button() or touch(), size(), split_screen(), operating_system(). Etc.
#
# 3. Design class for Butterfly. Such that butterfly has multiple colors, patters, nature of living, origin,
# living_in_pupa, living_as_caterpiller. Etc.

# %% [markdown]
# # TASK 1

# %%
class Umbrella:
    def open(self):
        print("yes")
    def close(self):
        print("no")
    def waterproof(self):
        print("yes")
# class Apple:
#     def type(self):
#         print("Fruit")
#     def color(self):
#         print("Red")
def calling(obj):
        obj.open()
        obj.close()
        obj.waterproof()
T1=Umbrella()
# A1=Apple()
calling(T1)
# calling(A1)
# Out:
# yes
# no
# yes

# %%
class Classic:
    def __init__(self,name):
        self.name= name
        print(self.name)
    def open(self):
        print("This Umbrella is open.")
    def close(self):
        print("This Umberlla is not close.")
    def waterproof(self):
        print("Microfiber fabric canopys to keep the rain off.")
        
class Snow:
    def __init__(self,name):
        self.name=  name
        print(self.name)
    def open(self):
        print("This Umbrella is not open.")
    def close(self):
        print("This Umberlla is close.")
    def waterproof(self):
        print("This Umberlla is waterproof and can protect you from snow.")

class Fashion:
    def __init__(self,name):
        self.name= name
        print(self.name)
    def open(self):
        print("This Umbrella is open.")
    def close(self):
        print("This Umbrella is not close.")
    def waterproof(self):
        print("This Umbrella is use in Fashion shows and most fashion umbrellas are not waterproof")
        
print('_'*36,"UMBRELLA",'_'*36)
c1= Classic("Classic Umbrella:")
c1.open()
c1.close()
c1.waterproof()
s1= Snow("Snow Umbrella:")
s1.open()
s1.close()
s1.waterproof()
f1= Fashion("Fashion Umbrella:")
f1.open()
f1.close()
f1.waterproof()
# Out:
# ____________________________________ UMBRELLA ____________________________________
# Classic Umbrella:
# This Umbrella is open.
# This Umberlla is not close.
# Microfiber fabric canopys to keep the rain off.
# Snow Umbrella:
# This Umbrella is not open.
# This Umberlla is close.
# This Umberlla is waterproof and can protect you from snow.
# Fashion Umbrella:
# This Umbrella is open.
# This Umbrella is not close.
# This Umbrella is use in Fashion shows and most fashion umbrellas are not waterproof

# %% [markdown]
# # TASK 2

# %%
class Keypad:
    def __init__(self,name):
        self.name= name
        print(self.name)
    def button(self):
        print("qwerty keyboard system.")
    def size(self):
        print("It has 4 inches screen.")
    def split_screen(self):
        print("No split screen system.")
    def operating_system(self):
        print("The Nokia Asha Dual Sim combines great entertainment features. \nWith up to 10 hours of talk time, \nWith 2000 mAH Battery, \nthe Nokia Asha gives you a backup for your complete day.")
        print("The 4″ screen is for best internet browsing for movies, taking and viewing pictures, playing videos and gaming.")
        print("Storage: 8Gb ROM And 2Gb RAM")
        
class Keypad_And_Touch:
    def __init__(self,name):
        self.name= name
        print(self.name)
    def button(self):
        print("It has a Keypad System.")
    def touch(self):
        print("It has a Touch System too.")
    def size(self):
        print("Dimensions:106.2 x 48.4 x 9.6 mm, 45.3 cc  . \nSize:2.4 inches  \nResolution: 240 x 320 pixels    ")
    def split_screen(self):
        print("No split screen system.")
    def operating_system(self):
        print("Nokia X3 02 Touch and Type  . \nTalktime:Up to 5 h 20 min  \nAudio: 3.5mm audio jack, Speakerphone") 
        print("Browser: Wi-FiWi-Fi 802.11 b/g/n  , dual-band, Wi-Fi Direct, hotspot  \nMessaging: SMS, MMS, Email, IM  \nGames: built-in   \nTorch: Yes  \nExtra: Speakerphone, Voice memo")
        print("Storage 50 MB Built-in  Card	microSD Card (supports up to 32GB) , \nWith 1500mAH Battery  \n	Main 5 MP, 2592 x 1944 pixels \n Features 5 MP (Full focus), 4x digital Zoom, Video (VGA 18fps)  \n Front No  ")      
        
class Touch:
    def __init__(self,name):
        self.name= name
        print(self.name)
    def touch(self):
        print("It has a Touch System.")
    def size(self):
        print("Size	6.21 Inches  \nResolution:720 x 1520 Pixels (~271 PPI)")
    def split_screen(self):
        print("Doesn'tSupport Split Screen System.")
    def operating_system(self):
        print("Accelerometer, Compass, Fingerprint (rear mounted), Gyro, Proximity  , G Sensor, Proximity  \nAudio: 3.5mm Audio Jack, MP4/H.264 player, MP3/eAAC+/WAV/Flac player, Speaker Phone") 
        print("Browser: HTML5  \nMessaging	SMS(threaded view), MMS, Email, Push Mail, IM  \nGames: Built-in + Downloadable  \nTorch: Yes")  
        print(" Photo/video editor, Document editor \nWith SD Card Slot \n	(Li-Po Non removable), 4000 mAh  ")
        print("64 Gb ROM And 4Gb Ram \nTriple Camera: 13 MP + 8 MP + 2 MP, Quad LED Flash \n Front 32")
        print("And aslo it contains Heartbeat sensor , Steps Counting And Also many features we found")
        

print(" ")
k1= Keypad("Nokia Asha")
k1.button()
k1.size()
k1.split_screen()
k1.operating_system()

tb1= Keypad_And_Touch( "\n""\n""Nokia X3")
tb1.button()
tb1.touch()
tb1.size()
tb1.split_screen()
tb1.operating_system()

t1= Touch("\n""\n""Infinix S4")
t1.touch()
t1.size()
t1.split_screen()
t1.operating_system()
# Out:
#
# Nokia Asha
# qwerty keyboard system.
# It has 4 inches screen.
# No split screen system.
# The Nokia Asha Dual Sim combines great entertainment features.
# With up to 10 hours of talk time,
# With 2000 mAH Battery,
# the Nokia Asha gives you a backup for your complete day.
# The 4″ screen is for best internet browsing for movies, taking and viewing pictures, playing videos and gaming.
# Storage: 8Gb ROM And 2Gb RAM
#
#
# Nokia X3
# It has a Keypad System.
# It has a Touch System too.
# Dimensions:106.2 x 48.4 x 9.6 mm, 45.3 cc  .
# Size:2.4 inches
# Resolution: 240 x 320 pixels
# No split screen system.
# Nokia X3 02 Touch and Type  .
# Talktime:Up to 5 h 20 min
# Audio: 3.5mm audio jack, Speakerphone
# Browser: Wi-FiWi-Fi 802.11 b/g/n  , dual-band, Wi-Fi Direct, hotspot
# Messaging: SMS, MMS, Email, IM
# Games: built-in
# Torch: Yes
# Extra: Speakerphone, Voice memo
# Storage 50 MB Built-in  Card	microSD Card (supports up to 32GB) ,
# With 1500mAH Battery
# ...

# %% [markdown]
# # TASK 3

# %%
class Morpho:
    def __init__(self,name):
        self.name= name
        print(self.name)
     #Pieridae
    def multiple_colors(self):
        print("The males have brilliant Green wings, while females are Light blue .")
    def nature_of_living(self):
        print("Many thousands can be seen emerging towards the end of a hot summer.")
    def origin(self):
        print("Origin: From London but restriced to US.")
    def size_family(self):
        print("Family: Green \nSize: Small/Medium \nWing Span Range (male to female): 44mm")
    def caterpiller_foodplant(self):
        print("The sole foodplant is Horseshoe Vetch (Morpho).")
        
class Falcate_orangetip:
    def __init__(self,name):
        self.name= name
        print(self.name)
        #Papilionidae
    def multiple_colors(self):
        print("It has brilliant Black wings, with Silver tips to the forewings .The undersides are a Blue.")
    def nature_of_living(self):
        print("This common butterfly is found in a variety of habitats, particularly gardens where cabbages are grown.")
    def origin(self):
        print("Origin: USA, IR, Wales and NZ.")
    def size_family(self):
        print("Family: Black and blue \nSize: small/Medium \n (male to female): 44mm")
    def caterpiller_foodplant(self):
        print("ultivated brassicas are used, especially cabbages, and Nasturtium (Falcate_orangetip) in gardens.Wild crucifers, including Wild Cabbage .")
        
class Burca :
    def __init__(self,name):
        self.name= name
        print(self.name)
        #Riodinidae
    def multiple_colors(self):
        print("Combination of Blue, Black and Orange colors.")
    def nature_of_living(self):
        print("This magnificent butterfly flies high in the tree-tops of well-wooded landscapes in central-southern Wales. ")
    def origin(self):
        print("Origin: London but Restriced to Southern and Central NZ.")
    def size_family(self):
        print("Family: Riodinidae \nSize: Large \nWing Span Range (male to female): 90mm")
    def caterpiller_foodplant(self):
        print("Lycaenidae ( Blues and Hairstreaks ) is the most widely used foodplant although it breeds on Grey Willow (Skipper). ")
       

    
print("BUTTERFLIES")

a1= Morpho("Arthropoda")
a1.multiple_colors()
a1.nature_of_living()
a1.origin()
a1.size_family()
a1.caterpiller_foodplant()

s1= Falcate_orangetip("\n""\n""Anthocharis Midea")
s1.multiple_colors()
s1.nature_of_living()
s1.origin()
s1.size_family()
s1.caterpiller_foodplant()

e1= Burca ("\n""\n""Genus")
e1.multiple_colors()
e1.nature_of_living()
e1.origin()
e1.size_family()
e1.caterpiller_foodplant()
# Out:
# BUTTERFLIES
# Arthropoda
# The males have brilliant Green wings, while females are Light blue .
# Many thousands can be seen emerging towards the end of a hot summer.
# Origin: From London but restriced to US.
# Family: Green
# Size: Small/Medium
# Wing Span Range (male to female): 44mm
# The sole foodplant is Horseshoe Vetch (Morpho).
#
#
# Anthocharis Midea
# It has brilliant Black wings, with Silver tips to the forewings .The undersides are a Blue.
# This common butterfly is found in a variety of habitats, particularly gardens where cabbages are grown.
# Origin: USA, IR, Wales and NZ.
# Family: Black and blue
# Size: small/Medium
#  (male to female): 44mm
# ultivated brassicas are used, especially cabbages, and Nasturtium (Falcate_orangetip) in gardens.Wild crucifers, including Wild Cabbage .
#
#
# Genus
# Combination of Blue, Black and Orange colors.
# This magnificent butterfly flies high in the tree-tops of well-wooded landscapes in central-southern Wales.
# ...
