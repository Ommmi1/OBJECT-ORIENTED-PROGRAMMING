# %%
from tkinter import *
from sqlite3 import *
import tkinter
import random
import tkinter.messagebox
import time
class CaliforniaPizza:
    def home(self):
        
        self.scr=Tk(className="California Pizza Management Home")
        
        self.scr.geometry("1366x768")
        
        self.scr.iconbitmap('p.ico')
        
        self.fr=Frame(self.scr,height=150,width=1366)
        
        self.fr=Frame(self.scr,bg="#660000",height=618,width=1366)
        
        self.c=Canvas(self.fr,height=618,width=1366)
        
        self.c.pack()
        
        self.logo1=PhotoImage(file="Page1.png")
        
        self.c.create_image(689,309,image=self.logo1)
        
        self.c.create_rectangle(300,300,600,500,fill="#660000",outline="white",width=2)
        
        self.user = StringVar()
        
        self.pasd = StringVar()
        
        self.st=Button(self.fr,text="LOGIN",command=self.login,fg="white",bg="#0b1335",font=("cooper black",20),bd=2)
        
        self.st.place(x=400,y=340)
        
        self.si=Button(self.fr,text="REGISTER",command=self.register,fg="white",bg="#0b1335",font=("cooper black",20),bd=2)
        
        
        self.si.place(x=370,y=425)
        
        self.fr.pack(fill=BOTH,expand=1)
        
        self.scr.mainloop()

        
        

    def register(self):
#         self.scr.destroy()
        
    
        self.scr1=Tk(className="Pizza Management Register")
        
        self.scr1.geometry("1366x768")
        
        self.scr1.iconbitmap('p.ico')
        
        
        self.fr=Frame(self.scr1,bg="#660000",height=550,width=650)
        
        self.lab3=Label(self.fr,text="CUSTOMER REGISTRATION",fg="white",bg="#0b1335",font=("cooper black",20),bd=2)
        
        self.lab3.place(x=250,y=50)

        
        self.lb1=Label(self.fr,text="FIRST NAME *",fg="white",bg="#0b1335",font=("cooper black",20),bd=2)
        
        self.lb1.place(x=80,y=130)
        
        self.first=Entry(self.fr,bg="#E3DCF1",width=15,font=("cooper black",20),bd=2)
        
        self.first.place(x=270,y=130)
        
        self.lab2=Label(self.fr,text="LAST NAME",fg="white",bg="#0b1335",font=("cooper black",20),bd=2)
        
        self.lab2.place(x=80,y=180)
        
        self.last=Entry(self.fr,bg="#E3DCF1",width=15,font=("default",20),bd=2)
        
        self.last.place(x=270,y=180)
        
        
        self.lab1=Label(self.fr,text="USERNAME *",fg="white",bg="#0b1335",font=("cooper black",20),bd=2)
        
        self.lab1.place(x=80,y=230)
        
        self.lab2=Label(self.fr,text="password *",fg="white",bg="#0b1335",font=("cooper black",20),bd=2)
        
        self.lab2.place(x=80,y=280)
        
        self.user=Entry(self.fr,bg="#E3DCF1",font=("default",20),bd=2)
        
        self.user.place(x=270,y=230)
        
        self.pasd=Entry(self.fr,bg="#E3DCF1",font=("default",20),bd=2,show="*")
        
        self.pasd.place(x=270,y=280)

        
        
        self.lab5=Label(self.fr,text="EMAIL ID *",fg="white",bg="#0b1335",font=("cooper black",20),bd=2)
        
        self.lab5.place(x=80,y=330)
        
        self.email=Entry(self.fr,bg="#E3DCF1",width=15,font=("cooper black",20),bd=2)
        
        self.email.place(x=270,y=330)
        
        self.lab6=Label(self.fr,text="MOBILE.",fg="white",bg="#0b1335",font=("cooper black",20),bd=2)
        
        self.lab6.place(x=80,y=380)
        
        self.mob=Entry(self.fr,bg="#E3DCF1",width=15,font=("default",20),bd=2)
        
        self.mob.place(x=270,y=380)
        
        self.st=Button(self.fr,text="SUBMIT",cursor="hand2",fg="white",bg="#0b1335",font=("cooper black",20),bd=2,command=self.Regdatabase)
        
        self.st.place(x=200,y=500)
        
        self.si=Button(self.fr,text="CLEAR",fg="white",bg="#0b1335",font=("cooper black",20),bd=2,command=self.clear)
        
        self.si.place(x=380,y=500)        
        
        self.fr.pack(fill=BOTH,expand=1)
        
        self.scr.mainloop()
        
        
        
    def login(self):
#         self.scr.destroy()
        
        self.scr1=Tk(className="Pizza Management Login")
        
        self.scr1.geometry("1000x500")
        
        self.scr1.iconbitmap('p.ico')
        
        self.fr=Frame(self.scr1,bg="#660000",height=400,width=600)
#         self.lab3=Label(self.fr,text="Login",bg="#0b1335",font=("default",20))
        
        self.lab3=Label(self.fr,text="LOGIN",fg="white",bg="#0b1335",width=26,font=("cooper black",27))
        
        self.lab3.place(x=250,y=50)
        
        self.lab1=Label(self.fr,text="USERNAME",bg="#E3DCF1",font=("default",20))
        
        self.lab1.place(x=80,y=150)
        
        self.lab2=Label(self.fr,text="PASSWORD",bg="#E3DCF1",font=("default",20))
        
        self.lab2.place(x=80,y=250)
        
        
        self.user=Entry(self.fr,bg="#E3DCF1",font=("default",20),textvariable=self.user)
        
        self.user.place(x=300,y=150)
        
        self.pasd=Entry(self.fr,bg="#E3DCF1",font=("default",20),show="*",textvariable=self.pasd)
        
        self.pasd.place(x=300,y=250)
        
        self.st=Button(self.fr,text="SUBMIT",font=("default",20),bg="#0b1335",fg="white",command=self.logindatabase)
        
        self.st.place(x=250,y=350)
        
        self.si=Button(self.fr,text="CLEAR",bg="#0b1335",fg="white",command=self.clear,font=("default",20))
        
        self.si.place(x=400,y=350)
        
        self.fr.pack(fill=BOTH,expand=1)
        
        self.scr.mainloop()
        
        
    def menu(self):
        
            self.scr1.destroy()
            
            self.scr3=Tk(className="MENU")
            
            self.scr3.geometry("1000x1000")
            
            self.scr3.iconbitmap('p.ico')
            
            self.fra=Frame(self.scr3,bg="#660000",height=800,width=2000)
            
            self.scr3.config(bg="#660000")
            
            
            
            self.c=Canvas(self.fra,height=600,width=600)
            
            
            self.c.pack()
            
            self.scr3.title("MENU")
            
            self.v1=IntVar()
            
            
            self.v2=IntVar()
            
            self.v3=IntVar()
            
            self.v4=IntVar()
            
            self.v5=IntVar()
            
            self.v6=IntVar()
            
            self.labe=Label(self.fra,text="ITEM",bg="#ff4d94",font=("cooper black",20))
            
            self.labe.place(x=150,y=30)
            
            self.labe1=Label(self.fra,text="PRICE",bg="#ff4d94",font=("cooper black",20))
            
            self.labe1.place(x=350,y=30)
            
            self.labe2=Label(self.fra,text="Veg Pizza",bg="#E3DCF1",font=("default",16))
            
            self.labe2.place(x=140,y=85)
            
            self.labe3=Label(self.fra,text="250",bg="#E3DCF1",font=("default",16))
            
            self.labe3.place(x=365,y=85)
            
            self.labe2=Label(self.fra,text="Deluxe Veggie",bg="#E3DCF1",font=("default",16))
            
            self.labe2.place(x=125,y=115)
            
            self.labe3=Label(self.fra,text="250",bg="#E3DCF1",font=("default",16))
            
            self.labe3.place(x=365,y=115)
            
            self.labe2=Label(self.fra,text="Veg Vaganza",bg="#E3DCF1",font=("default",16))
            
            self.labe2.place(x=125,y=145)
            
            self.labe3=Label(self.fra,text="250",bg="#E3DCF1",font=("default",16))
            
            self.labe3.place(x=365,y=145)
            
            self.labe2=Label(self.fra,text="Pepper Pizza",bg="#E3DCF1",font=("default",16))
            
            self.labe2.place(x=125,y=175)
            
            self.labe3=Label(self.fra,text="250",bg="#E3DCF1",font=("default",16))
            
            self.labe3.place(x=365,y=175)
            
            self.labe2=Label(self.fra,text="Margherita",bg="#E3DCF1",font=("default",16))
            
            self.labe2.place(x=135,y=205)
            
            self.labe3=Label(self.fra,text="195",bg="#E3DCF1",font=("default",16))
            
            self.labe3.place(x=365,y=205)
            
            self.labe4=Label(self.fra,text="Cold Drink",bg="#E3DCF1",font=("default",16))
            
            self.labe4.place(x=135,y=235)
            
            self.labe5=Label(self.fra,text="40",bg="#E3DCF1",font=("default",16))
            
            self.labe5.place(x=365,y=235)
            
            self.labe6=Label(self.fra,text="YOUR ORDER DETAILS",bg="#ff4d94",font=("Cooper black",16))
            
            self.labe6.place(x=155,y=280)
            
            self.lab7=Label(self.fra,text="Item",bg="#E3DCF1",font=("default",16))
            
            self.lab7.place(x=120,y=315)
            
            self.lab8=Label(self.fra,text="Quantity",bg="#E3DCF1",font=("default",16))
            
            self.lab8.place(x=280,y=315)
            
            self.lab9=Label(self.fra,text="Veg Pizza",bg="#E3DCF1",font=("default",16))
            
            self.lab9.place(x=90,y=350)
            
            self.v1=Entry(self.fra,bg="#E3DCF1",font=("default",16))
            
            self.v1.place(x=230,y=350)
            
            self.lab10=Label(self.fra,text="Deluxe Pizza",bg="#E3DCF1",font=("default",16))
            
            self.lab10.place(x=85,y=385)
            
            self.v2=Entry(self.fra,bg="#E3DCF1",font=("default",16))
            
            self.v2.place(x=230,y=385)
            
            self.lab11=Label(self.fra,text="Veg Vaganza",bg="#E3DCF1",font=("default",16))
            
            self.lab11.place(x=85,y=420)
            
            self.v3=Entry(self.fra,bg="#E3DCF1",font=("default",16))
            
            self.v3.place(x=230,y=420)
            
            self.lab12=Label(self.fra,text="Pepper Pizza",bg="#E3DCF1",font=("default",16))
            
            self.lab12.place(x=85,y=455)
            
            self.v4=Entry(self.fra,bg="#E3DCF1",font=("default",16))
            
            self.v4.place(x=230,y=455)
            
            self.lab13=Label(self.fra,text="Margherita",bg="#E3DCF1",font=("default",16))
            
            self.lab13.place(x=90,y=490)
            
            self.v5=Entry(self.fra,bg="#E3DCF1",font=("default",16))
            
            self.v5.place(x=230,y=490)
            
            self.lab14=Label(self.fra,text="Cold Drink",bg="#E3DCF1",font=("default",16))
            
            self.lab14.place(x=90,y=525)
            
            self.v6=Entry(self.fra,bg="#E3DCF1",font=("default",16))
            
            self.v6.place(x=230,y=525)
            
            self.to=Button(self.fra,text="SUBMIT",font=("cooper black",20),bg="#ffb3d1",fg="black",command=self.order)
            
            self.to.place(x=250,y=565)
            
            self.home=Button(self.fra,text="Log Out",command=lambda:self.scr3.destroy(),bg="#0b1335",cursor="hand2",fg="white",bd=5,font=("default",16,'bold'))
            
            self.home.place(x=470,y=30)
            
            self.to.pack(fill=BOTH,expand=1)
            
            self.fra.pack()
            
            self.scr3.mainloop()
            
            
    def order(self):
#         self.scr3.destroy()
        
        self.scr2=Tk(className="Place Order")
        self.scr2.geometry("450x300")
#         self.scr2.resizable(False, False)
        self.scr2.title("Place Order")
        self.scr2.config(bg="#660000")
        
        
        
        self.scr2.iconbitmap('p.ico')
        
        
        
#         self.scr2.config(bg="#660000")
        
        self.fram=Frame(self.scr2,height=618,width=1366,bg="#660000")
        
        self.a=self.v1.get()
        
        self.b=self.v2.get()
        
        self.c=self.v3.get()
        
        self.d=self.v4.get()
        
        self.e=self.v5.get()
        
        self.f=self.v6.get()
        if len(self.a)==0:
        
            self.a="0"
        if len(self.b)==0:
            self.b="0"
        if len(self.c)==0:
            self.c="0"
        if len(self.d)==0:
            self.d="0"
        if len(self.e)==0:
            self.e="0"
        if len(self.f)==0:
            self.f="0"
  
        self.sum=int(self.a)*250+int(self.b)*250+int(self.c)*250+int(self.d)*250+int(self.e)*195+int(self.f)*40



        
        self.c=Canvas(self.fram,height=450,width=1000)

        
        
        self.label_1 =Label(self.fram,text="Username: " + self.loguser,font=("default",16))
        
        self.label_1.place(x=500,y=120)
        
        self.label2=Label(self.fram,text="-----------------------------",font=("default",16))
        
        self.label2.place(x=470,y=90)
        
        self.label3=Label(self.fram,text="-----------------------------",font=("default",16))
        
        self.label3.place(x=470,y=340)
        self.label4=Label(self.fram,text="xxxxxxxxxxxxxxxxxxxxxxxxxxxxx",font=("default",16))
        
        self.label4.place(x=420,y=370)
        self.label5=Label(self.fram,text="WELCOME TO CALIFORNIA PIZZA ",font=("default",16))
        
        self.label5.place(x=400,y=30)
        
        self.localtime=time.asctime(time.localtime(time.time()))
        
        self.c.create_text(570,70,text=self.localtime,fill="black",font=("default",16))
        self.label5=Label(self.fram,text="THANK YOU FOR ORDERING",font=("default",16))
        
        self.label5.place(x=420,y=390)
        self.label6=Label(self.fram,text="VEG\nDELUXE VEGIE\nVEG VAGANZA\nPEPPER\nMARGHRIT\nCOLD DRINK",font=("default",16))
        
        self.label6.place(x=470,y=160)

        
        self.labell=Label(self.fram,text="Total payable amount is ",font=("default",16))
        self.labell.place(x=470,y=310)
        self.label7=Label(self.fram,text=random.randint(999,999999),font=("default",16))
        self.label7.place(x=820,y=70)
        
        self.val=Label(self.fram,text=self.sum,bg="#E3DCF1",font=("default",16))
        
        self.val.place(x=720,y=310)
        self.c.pack()
        
        self.fram.pack()
        
        self.scr.mainloop()
        
        
    def result(self):
        
        self.username=self.user.get()
        
        self.password=self.pasd.get()
        
        try:
            self.scr.destroy()
        except:
            try:
                self.scr1.destroy()
            except:
                pass
   

    def clear(self):
        
        self.user.delete(0,END)
        
        self.pasd.delete(0,END)
    
    def values(self):
        
        self.login()
        
        return self.username,self.password

       
    
    
    #for login databse 
    def resultlog(self):
        global loguser
        
        self.loguser=self.user.get()
        
        self.logpass=self.pasd.get()
        
        return self.loguser,self.logpass
    
    
    def logindatabase(self):
        self.credlog=self.resultlog()
        
        self.con=connect("pizza.db")
        
        self.cur=self.con.cursor()
        try:
            self.cur.execute("create table customer(username varchar(50) not null,password varchar(50) not null,first varchar(50) not null,last varchar(50) not null,email varchar(50),mob varchar(50) not null)")
        except:
            pass
        
        x=self.cur.execute("select count(*) from customer where username=%r and password=%r"%(self.credlog[0],self.credlog[1]))
        if list(x)[0][0]==0:
            if self.credlog[0]=="" or self.credlog[1]=="":
                messagebox.showinfo("Login","Empty Entry is not allowed")
            else:
                messagebox.showinfo("Login","You are Not Registered Yet")
            
        else:
            messagebox.showinfo("Login","You have Successelfully Log In\nWelcome to the California Pizza")            
            self.menu()
            
            
            
# for registrations database
    def resultreg(self):
        self.reguser=self.user.get()
        
        self.regpasd=self.pasd.get()
        
        self.firstname=self.first.get()
        
        self.lastname=self.last.get()
        
        self.Email=self.email.get()
        
        self.Mob=self.mob.get()
        
        return self.reguser,self.regpasd,self.firstname,self.lastname,self.Email,self.Mob
    
    
    
    
    
    def Regdatabase(self):
        
        self.credreg=self.resultreg()
        
        self.con=connect("pizza.db")
        
        self.cur=self.con.cursor()
        try:
            self.cur.execute("create table customer(username varchar(50) not null,password varchar(50) not null,first varchar(50) not null,last varchar(50) not null,email varchar(50),mob varchar(50) not null)")
        except:
            pass
        
        x=self.cur.execute("select count(*) from customer where username=%r and mob=%r "%(self.credreg[0],self.credreg[5]))
        
        if list(x)[0][0]==0:
            if self.credreg[0]=="" or self.credreg[1]=="" or self.credreg[2]=="" or self.credreg[3]=="" or self.credreg[5]=="":
                messagebox.showinfo("Register","Empty Entry is not Allowed(except Email)")
            else:
                self.cur.execute("insert into customer values(%r,%r,%r,%r,%r,%r)"%(self.credreg[0],self.credreg[1],self.credreg[2],self.credreg[3],self.credreg[4],self.credreg[5]))
                self.con.commit()
                messagebox.showinfo("Register","You are Successelfully Registered")
                self.login()
        else:
            messagebox.showinfo("Register","Username Already Exist \nEnter New Username")
            


x=CaliforniaPizza()
x.home()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\ommi\Anaconda3\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-1-91250527ca58>", line 500, in logindatabase
#     messagebox.showinfo("Login","You are Not Registered Yet")
# NameError: name 'messagebox' is not defined
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\ommi\Anaconda3\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-1-91250527ca58>", line 500, in logindatabase
#     messagebox.showinfo("Login","You are Not Registered Yet")
# NameError: name 'messagebox' is not defined
